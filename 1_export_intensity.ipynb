# %%
from glob import glob
import numpy as np
import cv2

# %%
from tqdm import tqdm
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
img = cv2.imread("frames/0001.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
# _runningAvg = np.zeros(img.shape, dtype=np.float32)

# %%
intensity = []
for f in tqdm(sorted(glob('frames/*.jpg'))):
    img = cv2.imread(f)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)/255
    s = np.sum(img)
#     cv2.accumulateWeighted(img, _runningAvg, 0.2)
    intensity.append(s)
# Out:
#  22%|██▏       | 2591/11951 [03:23<12:15, 12.73it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c35063fda989> in <module>
#       1 intensity = []
#       2 for f in tqdm(sorted(glob('frames/*.jpg'))):
# ----> 3     img = cv2.imread(f)
#       4     img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)/255
#       5     s = np.sum(img)
#
# KeyboardInterrupt:

# %%
plt.plot(intensity)

# %%
intensity
